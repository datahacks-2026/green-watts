# %% [markdown]
# # GridGreen Benchmark Tables
#
# Open this notebook after running:
#
# 1. `./.venv/bin/python evaluation/runner.py --config evaluation/configs/benchmark_config.json`
# 2. `./.venv/bin/python evaluation/metrics.py --run-dir evaluation/runs/<timestamp>`

# %%
from pathlib import Path
import pandas as pd

RUN_DIR = Path('evaluation/runs')
latest = sorted([p for p in RUN_DIR.iterdir() if p.is_dir()])[-1]
latest

# %%
t1 = pd.read_csv(latest / 'table1_system_comparison.csv')
t2 = pd.read_csv(latest / 'table2_reductions.csv')
t3 = pd.read_csv(latest / 'table3_accuracy.csv')
t4 = pd.read_csv(latest / 'table4_suggestion_quality.csv')

display(t1)
display(t2)
display(t3)
display(t4)

# %%
print((latest / 'report.md').read_text())
